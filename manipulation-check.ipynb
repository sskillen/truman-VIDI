# %%
import pandas as pd

# Load CSV file from local file system
# Replace 'path/to/your/file.csv' with your actual file path
df = pd.read_csv("C:\\Users\\skill002\\OneDrive - Wageningen University & Research\\CODE\\Pre-test_April+22,+2026_11.42\\Pre-test_April 22, 2026_11.42.csv")

# Display basic information about the data
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (35, 194)

# %%
print("\nColumn names:")
for col in df.columns:
    print(col)
# Out:
# Column names:
# StartDate
# EndDate
# Status
# IPAddress
# Progress
# Duration (in seconds)
# Finished
# RecordedDate
# ResponseId
# RecipientLastName
# RecipientFirstName
# RecipientEmail
# ExternalReference
# LocationLatitude
# LocationLongitude
# DistributionChannel
# UserLanguage
# consent
# control_2_1
# control_2_2
# control_2_3
# control_2_4
# control_2_5
# control_3_1
# control_3_2
# control_3_3
# control_3_4
# control_3_5
# control_4_1
# control_4_2
# control_4_3
# control_4_4
# control_4_5
# control_5_1
# control_5_2
# control_5_3
# control_5_4
# control_5_5
# control_1_1
# control_1_2
# control_1_3
# control_1_4
# control_1_5
# inciv_3_1
# inciv_3_2
# inciv_3_3
# inciv_3_4
# inciv_3_5
# inciv_1_1
# inciv_1_2
# inciv_1_3
# inciv_1_4
# inciv_1_5
# inciv_2_1
# inciv_2_2
# inciv_2_3
# inciv_2_4
# inciv_2_5
# inciv_5_1
# inciv_5_2
# inciv_5_3
# inciv_5_4
# inciv_5_5
# inciv_4_1
# inciv_4_2
# inciv_4_3
# inciv_4_4
# inciv_4_5
# intol_3_1
# intol_3_2
# intol_3_3
# intol_3_4
# ...

# %%
print("\nData types:")
print(df.dtypes)
# Out:
# Data types:
# StartDate                 str
# EndDate                   str
# Status                    str
# IPAddress                 str
# Progress                  str
#                          ...
# inciv_7_2                 str
# inciv_7_3                 str
# inciv_7_4                 str
# inciv_7_5                 str
# Q_DataPolicyViolations    str
# Length: 194, dtype: object

# %%
# See all unique values
print(df['inciv_7_2'].unique())
print(df['inciv_5_2'].)
# Out:
#   Cell In[5], line 3
#     print(df['inciv_5_2'].)
#                           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

cols_control = [
    'control_2_1', 'control_2_2', 'control_2_3', 'control_2_4', 'control_2_5',
    'control_3_1', 'control_3_2', 'control_3_3', 'control_3_4', 'control_3_5',
    'control_4_1', 'control_4_2', 'control_4_3', 'control_4_4', 'control_4_5',
    'control_5_1', 'control_5_2', 'control_5_3', 'control_5_4', 'control_5_5'
]

df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')

# %%
print(df[cols_control].describe())
# Out:
#        control_2_1  control_2_2  control_2_3  control_2_4  control_2_5  \
# count    11.000000    11.000000    11.000000    11.000000    11.000000
# mean      2.272727     1.636364     2.636364     2.454545     2.363636
# std       0.786245     0.809040     1.206045     1.128152     1.120065
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.000000     1.000000     1.500000     1.500000     1.000000
# 50%       2.000000     1.000000     3.000000     3.000000     3.000000
# 75%       2.500000     2.000000     3.500000     3.000000     3.000000
# max       4.000000     3.000000     4.000000     4.000000     4.000000
#
#        control_3_1  control_3_2  control_3_3  control_3_4  control_3_5  \
# count    12.000000    12.000000    12.000000    12.000000    12.000000
# mean      2.583333     1.250000     1.416667     1.416667     2.000000
# std       1.240112     0.621582     0.668558     0.792961     1.279204
# ...
